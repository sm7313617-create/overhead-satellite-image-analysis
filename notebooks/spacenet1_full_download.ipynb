# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install awscli
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 39.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 71.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.5/570.5 kB 29.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9.1
#     Uninstalling rsa-4.9.1:
#       Successfully uninstalled rsa-4.9.1
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.21.2
#     Uninstalling docutils-0.21.2:
#       Successfully uninstalled docutils-0.21.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sphinx 8.2.3 requires docutils<0.22,>=0.20, but you have docutils 0.19 which is incompatible.
# ...

# %%
# !mkdir -p /content/drive/MyDrive/SpaceNet1

# %%
# !aws s3 ls s3://spacenet-dataset/spacenet/SN1_buildings/tarballs/ --no-sign-request
# Out:
# 2019-11-05 19:56:34 1079959064 SN1_buildings_test_AOI_1_Rio_3band.tar.gz
# 2019-11-05 19:56:15  372882359 SN1_buildings_test_AOI_1_Rio_8band.tar.gz
# 2019-11-05 19:52:56 2571888708 SN1_buildings_train_AOI_1_Rio_3band.tar.gz
# 2019-11-05 19:53:36  893706368 SN1_buildings_train_AOI_1_Rio_8band.tar.gz
# 2019-11-05 19:54:09   21118272 SN1_buildings_train_AOI_1_Rio_geojson_buildings.tar.gz
# 2019-11-05 19:54:45   77789991 SN1_buildings_train_AOI_1_Rio_metadata.tar.gz

# %%
# !aws s3 cp s3://spacenet-dataset/spacenet/SN1_buildings/tarballs/SN1_buildings_train_AOI_1_Rio_3band.tar.gz /content/drive/MyDrive/SpaceNet1/ --no-sign-request
# Out:
# download: s3://spacenet-dataset/spacenet/SN1_buildings/tarballs/SN1_buildings_train_AOI_1_Rio_3band.tar.gz to drive/MyDrive/SpaceNet1/SN1_buildings_train_AOI_1_Rio_3band.tar.gz

# %%
# !aws s3 cp s3://spacenet-dataset/spacenet/SN1_buildings/tarballs/SN1_buildings_train_AOI_1_Rio_8band.tar.gz /content/drive/MyDrive/SpaceNet1/ --no-sign-request
# Out:
# download: s3://spacenet-dataset/spacenet/SN1_buildings/tarballs/SN1_buildings_train_AOI_1_Rio_8band.tar.gz to drive/MyDrive/SpaceNet1/SN1_buildings_train_AOI_1_Rio_8band.tar.gz

# %%
# !aws s3 cp s3://spacenet-dataset/spacenet/SN1_buildings/tarballs/SN1_buildings_train_AOI_1_Rio_geojson_buildings.tar.gz /content/drive/MyDrive/SpaceNet1/ --no-sign-request
# Out:
# download: s3://spacenet-dataset/spacenet/SN1_buildings/tarballs/SN1_buildings_train_AOI_1_Rio_geojson_buildings.tar.gz to drive/MyDrive/SpaceNet1/SN1_buildings_train_AOI_1_Rio_geojson_buildings.tar.gz

# %%
# !aws s3 cp s3://spacenet-dataset/spacenet/SN1_buildings/tarballs/SN1_buildings_train_AOI_1_Rio_metadata.tar.gz /content/drive/MyDrive/SpaceNet1/ --no-sign-request
# Out:
# download: s3://spacenet-dataset/spacenet/SN1_buildings/tarballs/SN1_buildings_train_AOI_1_Rio_metadata.tar.gz to drive/MyDrive/SpaceNet1/SN1_buildings_train_AOI_1_Rio_metadata.tar.gz

# %%
# !aws s3 cp s3://spacenet-dataset/spacenet/SN1_buildings/tarballs/SN1_buildings_test_AOI_1_Rio_3band.tar.gz /content/drive/MyDrive/SpaceNet1/ --no-sign-request
# Out:
# download: s3://spacenet-dataset/spacenet/SN1_buildings/tarballs/SN1_buildings_test_AOI_1_Rio_3band.tar.gz to drive/MyDrive/SpaceNet1/SN1_buildings_test_AOI_1_Rio_3band.tar.gz

# %%
# !aws s3 cp s3://spacenet-dataset/spacenet/SN1_buildings/tarballs/SN1_buildings_test_AOI_1_Rio_8band.tar.gz /content/drive/MyDrive/SpaceNet1/ --no-sign-request
# Out:
# download: s3://spacenet-dataset/spacenet/SN1_buildings/tarballs/SN1_buildings_test_AOI_1_Rio_8band.tar.gz to drive/MyDrive/SpaceNet1/SN1_buildings_test_AOI_1_Rio_8band.tar.gz

# %%
# !ls -lh /content/drive/MyDrive/SpaceNet1
# Out:
# total 4.7G
# -rw------- 1 root root 1.1G Nov  5  2019 SN1_buildings_test_AOI_1_Rio_3band.tar.gz
# -rw------- 1 root root 356M Nov  5  2019 SN1_buildings_test_AOI_1_Rio_8band.tar.gz
# -rw------- 1 root root 2.4G Nov  5  2019 SN1_buildings_train_AOI_1_Rio_3band.tar.gz
# -rw------- 1 root root 853M Nov  5  2019 SN1_buildings_train_AOI_1_Rio_8band.tar.gz
# -rw------- 1 root root  21M Nov  5  2019 SN1_buildings_train_AOI_1_Rio_geojson_buildings.tar.gz
# -rw------- 1 root root  75M Nov  5  2019 SN1_buildings_train_AOI_1_Rio_metadata.tar.gz

# %%
# !mkdir -p /content/drive/MyDrive/SpaceNet1/train
# !mkdir -p /content/drive/MyDrive/SpaceNet1/test

# %%
# !tar -xzf /content/drive/MyDrive/SpaceNet1/SN1_buildings_train_AOI_1_Rio_3band.tar.gz -C /content/drive/MyDrive/SpaceNet1/train

# %%
# !tar -xzf /content/drive/MyDrive/SpaceNet1/SN1_buildings_train_AOI_1_Rio_8band.tar.gz -C /content/drive/MyDrive/SpaceNet1/train

# %%
# !tar -xzf /content/drive/MyDrive/SpaceNet1/SN1_buildings_train_AOI_1_Rio_geojson_buildings.tar.gz -C /content/drive/MyDrive/SpaceNet1/train

# %%
# !tar -xzf /content/drive/MyDrive/SpaceNet1/SN1_buildings_train_AOI_1_Rio_metadata.tar.gz -C /content/drive/MyDrive/SpaceNet1/train

# %%
# !tar -xzf /content/drive/MyDrive/SpaceNet1/SN1_buildings_test_AOI_1_Rio_3band.tar.gz -C /content/drive/MyDrive/SpaceNet1/test

# %%
# !tar -xzf /content/drive/MyDrive/SpaceNet1/SN1_buildings_test_AOI_1_Rio_8band.tar.gz -C /content/drive/MyDrive/SpaceNet1/test
